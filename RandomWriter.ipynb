# %%
import random
import ipywidgets as widgets

categories = [
    "Action and/or Adventure",
    "Ghost Story",
    "Sci-Fi",
    "Drama",
    "Romantic Comedy",
    "Horror",
    "Fairy Tale and/or Fantasy",
    "Suspense and/or Thriller",
    "Historical Fiction",
    "Comedy",
    "Romance"
]

actions = [
    "Watering a plant",
    "Hiding in a basement",
    "Drawing with a crayon",
    "Burying something in a field",
    "Hiking a mountain",
    "Unplugging a laptop",
    "Getting dizzy",
    "Putting on slippers",
    "Channel surfing",
    "Putting air in a tire",
    "Starting a campfire",
    "Feeding a fish",
    "Winning a race",
    "Slapping someone",
    "Unfolding a letter",
    "Looking at a weather report",
    "Massaging a muscle",
    "Feeling nauseous",
    "Staining wood",
    "Feeding a cat",
    "Putting on fake eyelashes",
    "Exercising",
    "Scuba diving",
    "Tooting a horn",
    "Putting a message in a bottle",
    "Lighting a candle",
    "Using a power drill",
    "Shaving facial hair",
    "Pointing at something",
    "Staring at someone",
    "Swatting an insect",
    "Eating cornflakes",
    "Chopping wood",
    "Cashing a check",
    "Looking out an airplane window",
    "Turning on a fan",
    "Shivering",
    "Spray painting",
    "Breaking a vase",
    "Picking a berry",
    "Smelling",
    "Swimming in a river",
    "Finding a coin",
    "Feeding a dog",
    "Turning off a light",
    "Throwing a lifejacket",
    "Taking off shoes",
    "Eating an egg",
    "Cleaning up broken glass",
    "Getting goosebumps",
    "Tracing something",
    "Cutting out a coupon",
    "Brewing coffee",
    "Rowing a boat",
    "Sleeping in a bunk bed",
    "Reading a billboard",
    "Stealing a truck",
    "Wearing a scarf",
    "Grunting",
    "Drinking beer",
    "Shredding a document",
    "Writing something in wet cement",
    "Paying a toll",
    "Coughing",
    "Spreading butter",
    "Planting a vegetable",
    "Selling something",
    "Using a soap dispenser",
    "Getting a piercing",
    "Walking on a red carpet",
    "Putting a ring on a finger",
    "Changing a diaper",
    "Charging an electronic device",
    "Looking through someone else’s garbage",
    "Growling",
    "Leaving a voicemail",
    "Pulling someone’s hair",
    "Wandering",
    "Flipping a pancake",
    "Studying",
    "Peeling a vegetable",
    "Taking a door off its hinges",
    "Ordering dinner",
    "Drinking water",
    "Taking a ring off a finger",
    "Digging",
    "Collecting a reward",
    "Making a bet",
    "Wheezing",
    "Taking credit for someone else’s work",
    "Riding in a private jet",
    "Hiding in a closet",
    "Getting food poisoning",
    "Putting something in a washing machine",
    "Tasting something sour",
    "Rearranging furniture",
    "Stealing a bicycle",
    "Getting food from a drive-through",
    "Using a metal detector",
    "Waving a flag"
]

verbs = [
    "Catch",
    "Paper",
    "Approach",
    "Prep",
    "Mock",
    "Zero",
    "Wreck",
    "Social",
    "Clutch",
    "Over",
    "Shot",
    "Inter",
    "Aero",
    "Max",
    "Soul",
    "Amuse",
    "Sink",
    "Comb",
    "Tear",
    "Junk",
    "Lump",
    "Annual",
    "Large",
    "Mode",
    "Cook",
    "Track",
    "Mull",
    "Answer",
    "Essential",
    "Racy",
    "Dim",
    "Polite",
    "Just",
    "Opposite",
    "Off",
    "Done",
    "Rear",
    "Mall",
    "Very",
    "Out",
    "Dorm",
    "Parent",
    "Spark",
    "Armed",
    "Reason",
    "Fine",
    "Refer",
    "Beam",
    "Park",
    "Port",
    "Lite",
    "Reek",
    "Worn",
    "Pit",
    "Plea",
    "Fare",
    "Chant",
    "Lead",
    "Time",
    "Beat",
    "Square",
    "Horn",
    "New",
    "Cute",
    "Repair",
    "Verse",
    "Burden",
    "End",
    "Solve",
    "Faith",
    "Fight",
    "Upper",
    "List",
    "Chip",
    "Portion",
    "Middle",
    "Rid",
    "Bail",
    "Rate",
    "Brim",
    "Trot",
    "Stick",
    "Fore",
    "Pack",
    "Brisk",
    "Some",
    "Stone",
    "Mate",
    "Fund",
    "Rapid",
    "Call",
    "Second",
    "Gap",
    "Card",
    "Take",
    "Strike",
    "Tale",
    "Care",
    "Pop",
    "Due"
]

def generate_random_choice():
    category = random.choice(categories)
    action = random.choice(actions)
    verb = random.choice(verbs)
    return f"{category} / {action} / {verb}"

def on_button_clicked(b):
    output.clear_output()
    with output:
        print(generate_random_choice())

button = widgets.Button(description="Tell me what to write")
button.on_click(on_button_clicked)
output = widgets.Output()

display(widgets.VBox([button, output]))
